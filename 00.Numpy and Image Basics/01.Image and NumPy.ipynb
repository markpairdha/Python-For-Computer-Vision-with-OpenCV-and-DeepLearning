# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('siberian.jpg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x484 at 0x16D4802F3C8>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)
pic_arr.shape
# Out:
# (484, 736, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()
plt.imshow(pic_red)

# %%
type(pic_red)
# Out:
# numpy.ndarray

# %%
pic_red.shape
# Out:
# (484, 736, 3)

# %%
# R G B 
pic_red[:,:,0]
# Out:
# array([[ 76,  76,  74, ..., 167, 167, 167],
#        [ 78,  77,  76, ..., 168, 168, 168],
#        [ 81,  81,  81, ..., 169, 169, 169],
#        ...,
#        [201, 197, 198, ..., 112, 112, 112],
#        [192, 191, 191, ..., 113, 113, 113],
#        [190, 192, 192, ..., 114, 114, 114]], dtype=uint8)

# %%
plt.imshow(pic_arr[:,:,0])

# %%
plt.imshow(pic_arr[:,:,1])

# %%
plt.imshow(pic_arr[:,:,2])

# %%
pic_red[:,:,0] = 0 
# red is washed out,mixture of green and blue
plt.imshow(pic_red)

# %%
pic_red[:,:,1] = 0
# R & G washed out,only blue
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 0
plt.imshow(pic_red)
