# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr = np.ones((5,5))*10
arr
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
np.random.seed(101)
arr1 = np.random.randint(0,100,(5,5))
arr1
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
arr1.max()
# Out:
# 95

# %%
arr1.min()
# Out:
# 4

# %%
arr1.argmax()
# Out:
# 0

# %%
arr1.argmin()
# Out:
# 10

# %%
from PIL import Image

# %%
pic = Image.open('prabhas.jpg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1100x600 at 0x1A1E5B08160>

# %%
arr2 = np.asarray(pic)
plt.imshow(arr2)

# %%
arr2.shape
# Out:
# (600, 1100, 3)

# %%
plt.imshow(arr2[:,:,0])

# %%
plt.imshow(arr2[:,:,1])

# %%
plt.imshow(arr2[:,:,2])
